# %% [markdown]
# <a href="https://colab.research.google.com/github/darkaruna78/AIFFEL_quest_eng/blob/main/Python/Py03/PythonQuest_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [프로그램 개요]
#
# 사용자로부터 두 개의 정수와 **연산자(+, -, *, /, **)**를 입력받아 계산 결과를 출력하는 프로그램을 작성
#
# [상세 조건]
#
# 정수 입력 예외 처리: 사용자가 입력한 값이 정수가 아닌 경우 ValueError를 처리하여 적절한 오류
# 메시지를 출력해야 합니다.
#
# 입력 반복: 정수가 입력될 때까지 **"잘못된 입력입니다. 정수를 입력해주세요."**를 출력하며 다시 입력을 시도합니다.
#
# 0으로 나누기 제한: 나눗셈 연산 시 두 번째 정수가 0인 경우 ZeroDivisionError를 처리하여 적절한 오류 메시지를 출력합니다.
#
# 지원하지 않는 연산자: 사용자가 목록에 없는 연산자를 입력한 경우 적절한 오류 메시지를 출력합니다.
#
# math 모듈 활용: 제곱 연산(**)은 파이썬 내장 math 모듈을 사용하여 지원합니다.
#
# 반복 여부 확인: 계산이 완료된 후 계산기를 통해 계속 계산을 진행할 것인지 입력을 받습니다.

# %%
import math

def get_integer(prompt):
    """정수를 입력받을 때까지 반복하는 함수"""
    while True:
        try:
            return int(input(prompt))
        except ValueError:
            print("잘못된 입력입니다. 정수를 입력해주세요.")

# %%
# while True:
#     try:
#         num1 = int(input("첫 번째 정수를 입력하세요: "))
#         break # 정수 입력 성공 시 내부 루프 탈출
#     except ValueError:
#         print("잘못된 입력입니다. 정수를 입력해주세요.")

# while True:
#     try:
#         num2 = int(input("두 번째 정수를 입력하세요: "))
#         break # 정수 입력 성공 시 내부 루프 탈출
#     except ValueError:
#         print("잘못된 입력입니다. 정수를 입력해주세요.")
# Out:
# 첫 번째 정수를 입력하세요: 5
# 두 번째 정수를 입력하세요: 6

# %%
def get_operator():
    """올바른 연산자를 입력받을 때까지 반복하는 함수"""
    valid_operators = ['+', '-', '*', '/', '**']
    while True:
        op = input(f"연산자를 입력하세요 ({', '.join(valid_operators)}): ")
        # op = input(f"연산자를 입력하세요. '+', '-', '*', '/', '**' ")
        if op in valid_operators:
            return op
        else:
            print(f"잘못된 입력입니다. {valid_operators} 중 하나를 입력해주세요.")

# %%
def run_calculator():
    print("=== 파이썬 계산기 ===")

    while True:
        # 1. 정수 입력 받기 (올바른 값일 때까지 반복)
        num1 = get_integer("\n첫 번째 정수를 입력하세요: ")
        num2 = get_integer("두 번째 정수를 입력하세요: ")

        # 2. 연산자 입력 받기 (올바른 값일 때까지 반복)
        operator = get_operator()

        # 3. 연산 수행 및 예외 처리
        try:
            if operator == '+':
                result = num1 + num2
            elif operator == '-':
                result = num1 - num2
            elif operator == '*':
                result = num1 * num2
            elif operator == '/':
                result = num1 / num2
            elif operator == '**':
                # math 모듈을 사용하여 제곱 연산 수행
                result = math.pow(num1, num2)

            print(f">>> 계산 결과: {result}")

        except ZeroDivisionError:
            print("오류: 0으로 나눌 수 없습니다.")


        # 4. 계속 계산할지 여부 확인
        cont = input("\n계속 계산하시겠습니까? (종료: n / 계속: 아무 키): ").lower()
        if cont == 'n':
            print("종료합니다.")
            break
        print("-" * 40)

# %%
if __name__ == "__main__":
    run_calculator()
# Out:
# === 파이썬 계산기 ===
#
# 첫 번째 정수를 입력하세요: n
# 잘못된 입력입니다. 정수를 입력해주세요.
#
# 첫 번째 정수를 입력하세요: 6
# 두 번째 정수를 입력하세요: 4
# 연산자를 입력하세요 (+, -, *, /, **): /
# >>> 계산 결과: 1.5
#
# 계속 계산하시겠습니까? (종료: n / 계속: 아무 키): n
# 종료합니다.

# %% [markdown]
# ---
