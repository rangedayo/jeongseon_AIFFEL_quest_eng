# %%
# ! mkdir ~/work/motorcycle
# ! pip install kaggle
# Out:
#   Cell In[1], line 1
#     $ mkdir ~/work/motorcycle
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# kaggle 가입 후 아래 주소를 복사해 user_name 자리에 자신의 아이디를 넣은 후 접속해주세요.
# https://www.kaggle.com/<user_name>/account
# Create Legacy API Key를 선택하여 kaggle.json 파일을 다운로드 받습니다.
# kaggle.json 파일을 lms 클라우드에 업로드합니다.
# cloud shell에서 아래 코드를 실행시켜주세요. kaggle.json 파일을 업로드한 위치에 맞춰 코드를 수정해주세요.
# 실행 되었습니다.

# %%
# $ mkdir ~/.kaggle
# $ mv kaggle.json ~/.kaggle/kaggle.json
# $ cd ~/work/motorcycle
# $ kaggle datasets download -d sadhliroomyprime/motorcycle-night-ride-semantic-segmentation
# $ unzip motorcycle-night-ride-semantic-segmentation.zip

# %%
# mkdir masks
# Out:
# mkdir: cannot create directory ‘masks’: File exists

# %%
# find . -name "*save*" -exec mv {} ../masks/ \;
# Out:
#   Cell In[4], line 1
#     find . -name "*save*" -exec mv {} ../masks/ \;
#            ^
# SyntaxError: invalid syntax
